# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

os.listdir()
# Out:
# ['Capstone_Project_2.ipynb',
#  'customer subscription churn usage patterns - customer_subscription_churn_usage_patterns.csv']

# %%
os.listdir()
# Out:
# ['Capstone_Project_2.ipynb',
#  'customer subscription churn usage patterns - customer_subscription_churn_usage_patterns.csv']

# %%
df = pd.read_csv("customer subscription churn usage patterns - customer_subscription_churn_usage_patterns.csv")

# %%
df.head()
# Out:
#    user_id signup_date plan_type  monthly_fee  avg_weekly_usage_hours  \
# 0        1  2023-04-15   Premium          699                     1.1
# 1        2  2023-08-27   Premium          699                     2.6
# 2        3  2023-10-12   Premium          699                    14.3
# 3        4  2023-12-11     Basic          199                    17.6
# 4        5  2023-02-14     Basic          199                     9.8
#
#    support_tickets  payment_failures  tenure_months  last_login_days_ago churn
# 0                4                 1              8                   14   Yes
# 1                6                 0             35                    1   Yes
# 2                8                 3              2                   14   Yes
# 3                5                 2             11                    9   Yes
# 4                5                 2              6                   38   Yes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 2800 non-null   int64
#  1   signup_date             2800 non-null   str
#  2   plan_type               2800 non-null   str
#  3   monthly_fee             2800 non-null   int64
#  4   avg_weekly_usage_hours  2800 non-null   float64
#  5   support_tickets         2800 non-null   int64
#  6   payment_failures        2800 non-null   int64
#  7   tenure_months           2800 non-null   int64
#  8   last_login_days_ago     2800 non-null   int64
#  9   churn                   2800 non-null   str
# dtypes: float64(1), int64(6), str(3)
# memory usage: 218.9 KB

# %%
df.shape
# Out:
# (2800, 10)

# %%
df.columns
# Out:
# Index(['user_id', 'signup_date', 'plan_type', 'monthly_fee',
#        'avg_weekly_usage_hours', 'support_tickets', 'payment_failures',
#        'tenure_months', 'last_login_days_ago', 'churn'],
#       dtype='str')

# %%
df.describe()
# Out:
#            user_id  monthly_fee  avg_weekly_usage_hours  support_tickets  \
# count  2800.000000  2800.000000             2800.000000      2800.000000
# mean   1400.500000   434.214286               12.891429         3.887857
# std     808.434702   205.678472                7.109691         2.606419
# min       1.000000   199.000000                0.500000         0.000000
# 25%     700.750000   199.000000                6.700000         2.000000
# 50%    1400.500000   399.000000               12.800000         4.000000
# 75%    2100.250000   699.000000               19.200000         6.000000
# max    2800.000000   699.000000               25.000000         8.000000
#
#        payment_failures  tenure_months  last_login_days_ago
# count       2800.000000    2800.000000          2800.000000
# mean           2.491786      18.612857            30.005000
# std            1.691647      10.374487            17.852757
# min            0.000000       1.000000             0.000000
# ...

# %%
df.isnull().sum()
# Out:
# user_id                   0
# signup_date               0
# plan_type                 0
# monthly_fee               0
# avg_weekly_usage_hours    0
# support_tickets           0
# payment_failures          0
# tenure_months             0
# last_login_days_ago       0
# churn                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['avg_weekly_usage_hours'].mean()
# Out:
# np.float64(12.891428571428571)

# %%
df.groupby('plan_type')['avg_weekly_usage_hours'].mean()
# Out:
# plan_type
# Basic       13.156663
# Premium     12.627225
# Standard    12.896356
# Name: avg_weekly_usage_hours, dtype: float64

# %%
sns.barplot(
    data=df,
    x='plan_type',
    y='avg_weekly_usage_hours'
)
plt.title("Usage Hours by Subscription Plan")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x='tenure_months',
    y='avg_weekly_usage_hours'
)
plt.title("Usage vs Tenure")
plt.show()

# %%
df['churn'].value_counts()
# Out:
# churn
# Yes    1605
# No     1195
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='churn')
plt.title("Customer Churn Distribution")
plt.show()

# %%
pd.crosstab(df['plan_type'], df['churn'])
# Out:
# churn       No  Yes
# plan_type
# Basic      389  534
# Premium    396  548
# Standard   410  523

# %%
sns.countplot(data=df, x='plan_type', hue='churn')
plt.title("Churn by Subscription Plan")
plt.show()

# %%
sns.boxplot(
    data=df,
    x='churn',
    y='avg_weekly_usage_hours'
)
plt.title("Usage Hours vs Churn")
plt.show()

# %%
sns.boxplot(
    data=df,
    x='churn',
    y='tenure_months'
)
plt.title("Tenure vs Churn")
plt.show()

# %%
sns.boxplot(
    data=df,
    x='churn',
    y='payment_failures'
)
plt.title("Payment Failures vs Churn")
plt.show()

# %%
df.groupby('plan_type')['monthly_fee'].mean()
# Out:
# plan_type
# Basic       199.0
# Premium     699.0
# Standard    399.0
# Name: monthly_fee, dtype: float64

# %%
sns.barplot(
    data=df,
    x='plan_type',
    y='monthly_fee'
)
plt.title("Average Revenue by Plan")
plt.show()

# %%
sns.scatterplot(
    data=df,
    x='avg_weekly_usage_hours',
    y='monthly_fee'
)
plt.title("Revenue vs Usage")
plt.show()

# %%
sns.boxplot(
    data=df,
    x='churn',
    y='support_tickets'
)
plt.title("Support Tickets vs Churn")
plt.show()

# %%
sns.barplot(
    data=df,
    x='plan_type',
    y='support_tickets'
)
plt.title("Support Tickets by Plan")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("customer subscription churn usage patterns - customer_subscription_churn_usage_patterns.csv")

# %%
df.head()
# Out:
#    user_id signup_date plan_type  monthly_fee  avg_weekly_usage_hours  \
# 0        1  2023-04-15   Premium          699                     1.1
# 1        2  2023-08-27   Premium          699                     2.6
# 2        3  2023-10-12   Premium          699                    14.3
# 3        4  2023-12-11     Basic          199                    17.6
# 4        5  2023-02-14     Basic          199                     9.8
#
#    support_tickets  payment_failures  tenure_months  last_login_days_ago churn
# 0                4                 1              8                   14   Yes
# 1                6                 0             35                    1   Yes
# 2                8                 3              2                   14   Yes
# 3                5                 2             11                    9   Yes
# 4                5                 2              6                   38   Yes

# %%
import sweetviz as sv

report = sv.analyze(df)
report.show_html("SaaS_Customer_Churn_Report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SaaS_Customer_Churn_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
